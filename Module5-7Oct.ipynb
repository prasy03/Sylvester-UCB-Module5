# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'Batting':[45,55,65,75], 'Bowling':[8,9,6,5], 'Catches':[0,1,3,2]}, index = ['Sachin', 'Dravid', 'MSD', 'Koli'])
print(df)
# Out:
#         Batting  Bowling  Catches
# Sachin       45        8        0
# Dravid       55        9        1
# MSD          65        6        3
# Koli         75        5        2

# %%
ans_1 = ''
ans_1=df.isin([45, 6])
# print(type(ans_1))
print(ans_1)
# Out:
#         Batting  Bowling  Catches
# Sachin     True    False    False
# Dravid    False    False    False
# MSD       False     True    False
# Koli      False    False    False

# %%
values = {'Bowling': [5], 'Catches': [0]}
ans_2 = df.isin(values)
print(ans_2)
# Out:
#         Batting  Bowling  Catches
# Sachin    False    False     True
# Dravid    False    False    False
# MSD       False    False    False
# Koli      False     True    False

# %%
ans_3 = df.query("Bowling > 5")
print(type(ans_3))
ans_3
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         Batting  Bowling  Catches
# Sachin       45        8        0
# Dravid       55        9        1
# MSD          65        6        3

# %%
ans_4 = df.query("Batting > 30 and Bowling >6")
print(type(ans_4))
ans_4
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         Batting  Bowling  Catches
# Sachin       45        8        0
# Dravid       55        9        1

# %%
ans_5 = df.query('team.str.startswith("k")', engine = "python")
print(type(ans_5))
ans_5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/PythonProject-Test22July/.venv/lib/python3.13/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/collections/__init__.py:1019, in ChainMap.__getitem__(self, key)
#    1018         pass
# -> 1019 return self.__missing__(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/collections/__init__.py:1011, in ChainMap.__missing__(self, key)
#    1010 def __missing__(self, key):
# -> 1011     raise KeyError(key)
#
# KeyError: 'team'
#
# During handling of the above exception, another exception occurred:
# ...

# %% [markdown]
# #### Assignment 3_1 = Emcode

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gapminder = px.data.gapminder()
gapminder.info()
# gapminder.continent.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
print(gapminder)
gp1 = gapminder.loc('pop', 'country')
# print(gp1)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
plt.hist(gapminder['lifeExp'])
plt.title('Histogram of Life Expentancy')
plt.savefig('plot1.png')

# %%
sns.boxplot(x='lifeExp', y='continent', data=gapminder )
plt.savefig('plot2.png')

# %%
sns.boxplot(x='gdpPercap', y='continent', data=gapminder )
plt.savefig('plot3.png')

# %%
sns.scatterplot(x='gdpPercap', y='lifeExp', data=gapminder)
plt.savefig('plot4.png')

# %% [markdown]
# #### Self Study Colab 3.2

# %%
import plotly.express as px
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
gapminder = px.data.gapminder()
# print.gapminder
# gapminder.sample(5)
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
gapminder.tail(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182       ZWE
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071       ZWE
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176       ZWE
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682       ZWE
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041       ZWE
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1694      716
# 1695      716
# 1696      716
# 1697      716
# 1698      716
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %%
gapminder.sample(1703)
gapminder = px.data.gapminder()
print(gapminder)

# mean1 = gapminder.mean(lifeExp)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gapminder = px.data.gapminder()
print(gapminder)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gapminder_year = sum(gapminder.query('year == 1962')['gdpPercap'])
print(gapminder_year)
# df = gapminder[['gdpPercap', 'year']]
# sum(df.query('year == 1992') ['gdpPercap'])
# print(df)
# Out:
# 671065.3525586

# %%
for i in range(1952, 2007):
    print(f"gdp in the year {i} is" +str(sum(gapminder.query(f"year == {i}")["gdpPercap"])))
# Out:
# gdp in the year 1952 is528989.1985038
# gdp in the year 1953 is0
# gdp in the year 1954 is0
# gdp in the year 1955 is0
# gdp in the year 1956 is0
# gdp in the year 1957 is610515.9849724
# gdp in the year 1958 is0
# gdp in the year 1959 is0
# gdp in the year 1960 is0
# gdp in the year 1961 is0
# gdp in the year 1962 is671065.3525586
# gdp in the year 1963 is0
# gdp in the year 1964 is0
# gdp in the year 1965 is0
# gdp in the year 1966 is0
# gdp in the year 1967 is778678.7326506
# gdp in the year 1968 is0
# gdp in the year 1969 is0
# gdp in the year 1970 is0
# gdp in the year 1971 is0
# gdp in the year 1972 is961351.7597701
# gdp in the year 1973 is0
# gdp in the year 1974 is0
# gdp in the year 1975 is0
# gdp in the year 1976 is0
# gdp in the year 1977 is1038469.6317528
# gdp in the year 1978 is0
# gdp in the year 1979 is0
# gdp in the year 1980 is0
# gdp in the year 1981 is0
# gdp in the year 1982 is1067684.0375232
# gdp in the year 1983 is0
# gdp in the year 1984 is0
# ...

# %%
gapminder.groupby("year").agg(sum)[["gdpPercap"]]
# Out:
# /var/folders/g6/j22cb4pd2bj6ymv0l2glrvkr0000gn/T/ipykernel_998/444639672.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   gapminder.groupby("year").agg(sum)[["gdpPercap"]]
#          gdpPercap
# year
# 1952  5.289892e+05
# 1957  6.105160e+05
# 1962  6.710654e+05
# 1967  7.786787e+05
# 1972  9.613518e+05
# 1977  1.038470e+06
# 1982  1.067684e+06
# 1987  1.121931e+06
# 1992  1.158522e+06
# 1997  1.290805e+06
# 2002  1.408334e+06
# 2007  1.658570e+06

# %%
prob_1 = gapminder[["year", "lifeExp"]]
print(prob_1)
ans_1 = gapminder.groupby("year")[["lifeExp"]].mean()
print(ans_1)


# ans_1 = gapminder.groupby("year").agg(mean) [["lifeExp"]]
# ans_1
# Out:
#       year  lifeExp
# 0     1952   28.801
# 1     1957   30.332
# 2     1962   31.997
# 3     1967   34.020
# 4     1972   36.088
# ...    ...      ...
# 1699  1987   62.351
# 1700  1992   60.377
# 1701  1997   46.809
# 1702  2002   39.989
# 1703  2007   43.487
#
# [1704 rows x 2 columns]
#         lifeExp
# year
# 1952  49.057620
# 1957  51.507401
# 1962  53.609249
# 1967  55.678290
# 1972  57.647386
# 1977  59.570157
# 1982  61.533197
# 1987  63.212613
# 1992  64.160338
# 1997  65.014676
# 2002  65.694923
# 2007  67.007423

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
ans2 = gapminder.groupby("continent")[("gdpPercap")].mean()
print(ans2)
# Out:
# continent
# Africa       2193.754578
# Americas     7136.110356
# Asia         7902.150428
# Europe      14469.475533
# Oceania     18621.609223
# Name: gdpPercap, dtype: float64

# %%
ans3 = gapminder.groupby("continent")[("gdpPercap")].agg(['mean', 'median','std'])

print(ans3)
# Out:
#                    mean        median           std
# continent
# Africa      2193.754578   1192.138217   2827.929863
# Americas    7136.110356   5465.509853   6396.764112
# Asia        7902.150428   2646.786844  14045.373112
# Europe     14469.475533  12081.749115   9355.213498
# Oceania    18621.609223  17983.303955   6358.983321

# %%
ans4 = gapminder.groupby(gapminder["pop"] > 300_000_000)[("lifeExp")].mean()
print(ans4)
# Out:
# pop
# False    59.491833
# True     58.306267
# Name: lifeExp, dtype: float64

# %%
ans5a = gapminder[gapminder["continent"].isin(["Americas", "Europe"])]
# print(ans5a)
ans5b = ans5a.groupby(["continent", "country"])[("lifeExp")].mean()
print(ans5b)
# Out:
# continent  country
# Americas   Argentina                 69.060417
#            Bolivia                   52.504583
#            Brazil                    62.239500
#            Canada                    74.902750
#            Chile                     67.430917
#            Colombia                  63.897750
#            Costa Rica                70.181417
#            Cuba                      71.045083
#            Dominican Republic        61.554500
#            Ecuador                   62.816833
#            El Salvador               59.633333
#            Guatemala                 56.729417
#            Haiti                     50.165250
#            Honduras                  57.920833
#            Jamaica                   68.749333
#            Mexico                    65.408833
#            Nicaragua                 58.349417
#            Panama                    67.801750
#            Paraguay                  66.809083
# ...

# %%
sns.lineplot(x="year", y="gdpPercap", data=gapminder)
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
gapminder.groupby('year').agg(min)
# Out:
# /var/folders/g6/j22cb4pd2bj6ymv0l2glrvkr0000gn/T/ipykernel_998/1374565999.py:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   gapminder.groupby('year').agg(min)
#           country continent  lifeExp     pop   gdpPercap iso_alpha  iso_num
# year
# 1952  Afghanistan    Africa   28.801   60011  298.846212       AFG        4
# 1957  Afghanistan    Africa   30.332   61325  335.997115       AFG        4
# 1962  Afghanistan    Africa   31.997   65345  355.203227       AFG        4
# 1967  Afghanistan    Africa   34.020   70787  349.000000       AFG        4
# 1972  Afghanistan    Africa   35.400   76595  357.000000       AFG        4
# 1977  Afghanistan    Africa   31.220   86796  371.000000       AFG        4
# 1982  Afghanistan    Africa   38.445   98593  424.000000       AFG        4
# ...

# %%
gapminder.query('country == "Afghanistan"')
# Out:
#         country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439       AFG
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945       AFG
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395       AFG
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351       AFG
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055       AFG
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338       AFG
#
#     iso_num
# ...

# %%
gapminder.sort_values(by=['gdpPercap'], ascending=True, inplace=True)
gapminder.tail()
# Out:
#     country continent  year  lifeExp     pop     gdpPercap iso_alpha  iso_num
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326       KWT      414
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176       KWT      414
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290       KWT      414
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700       KWT      414
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290       KWT      414

# %%
def get_first_item(s):
    return s.iloc[0]
gapminder.sort_values("gdpPercap").groupby("year").agg(get_first_item)
print([gapminder])
# Out:
# [              country continent  year  lifeExp       pop      gdpPercap  \
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852     241.165876
# 335  Congo, Dem. Rep.    Africa  2007   46.462  64606759     277.551859
# 876           Lesotho    Africa  1952   42.138    748747     298.846212
# 624     Guinea-Bissau    Africa  1952   32.500    580653     299.850319
# 333  Congo, Dem. Rep.    Africa  1997   42.587  47798986     312.188423
# ..                ...       ...   ...      ...       ...            ...
# 855            Kuwait      Asia  1967   64.624    575003   80894.883260
# 854            Kuwait      Asia  1962   60.470    358266   95458.111760
# 852            Kuwait      Asia  1952   55.565    160000  108382.352900
# 856            Kuwait      Asia  1972   67.712    841934  109347.867000
# 853            Kuwait      Asia  1957   58.033    212846  113523.132900
#
#     iso_alpha  iso_num
# 334       COD      180
# 335       COD      180
# 876       LSO      426
# ...

# %%
gapminder.query('country == "Kuwait"')
# Out:
#     country continent  year  lifeExp      pop     gdpPercap iso_alpha  iso_num
# 859  Kuwait      Asia  1987   74.174  1891487   28118.42998       KWT      414
# 858  Kuwait      Asia  1982   71.309  1497494   31354.03573       KWT      414
# 860  Kuwait      Asia  1992   75.190  1418095   34932.91959       KWT      414
# 862  Kuwait      Asia  2002   76.904  2111561   35110.10566       KWT      414
# 861  Kuwait      Asia  1997   76.156  1765345   40300.61996       KWT      414
# 863  Kuwait      Asia  2007   77.588  2505559   47306.98978       KWT      414
# 857  Kuwait      Asia  1977   69.343  1140357   59265.47714       KWT      414
# 855  Kuwait      Asia  1967   64.624   575003   80894.88326       KWT      414
# 854  Kuwait      Asia  1962   60.470   358266   95458.11176       KWT      414
# 852  Kuwait      Asia  1952   55.565   160000  108382.35290       KWT      414
# 856  Kuwait      Asia  1972   67.712   841934  109347.86700       KWT      414
# ...

# %%
gapminder.sort_values(by=['gdpPercap']).groupby("year").first()
# Out:
#                country continent  lifeExp       pop   gdpPercap iso_alpha  \
# year
# 1952           Lesotho    Africa   42.138    748747  298.846212       LSO
# 1957           Lesotho    Africa   45.047    813338  335.997115       LSO
# 1962           Burundi    Africa   42.045   2961915  355.203227       BDI
# 1967           Myanmar      Asia   49.379  25870271  349.000000       MMR
# 1972           Myanmar      Asia   53.070  28466390  357.000000       MMR
# 1977           Myanmar      Asia   56.059  31528087  371.000000       MMR
# 1982           Myanmar      Asia   58.056  34680442  424.000000       MMR
# 1987           Myanmar      Asia   58.339  38028578  385.000000       MMR
# 1992           Myanmar      Asia   59.320  40546538  347.000000       MMR
# 1997  Congo, Dem. Rep.    Africa   42.587  47798986  312.188423       COD
# 2002  Congo, Dem. Rep.    Africa   44.966  55379852  241.165876       COD
# 2007  Congo, Dem. Rep.    Africa   46.462  64606759  277.551859       COD
#
# ...

# %%
ans = gapminder.groupby("continent")[["lifeExp"]].mean()
ans1 = ans.sort_values('lifeExp', ascending=False)
print(ans1)
# Out:
#              lifeExp
# continent
# Oceania    74.326208
# Europe     71.903686
# Americas   64.658737
# Asia       60.064903
# Africa     48.865330

# %%
ans = gapminder.groupby("continent")[["lifeExp"]].mean()
ans1 = ans.sort_values('lifeExp', ascending=False)
print(ans1)
# Out:
#              lifeExp
# continent
# Oceania    74.326208
# Europe     71.903686
# Americas   64.658737
# Asia       60.064903
# Africa     48.865330

# %%
ans = gapminder.groupby("country")[['gdpPercap']].mean().sort_values(by = 'gdpPercap', ascending=False)
ans2 = ans.iloc[0:1,0:0]
print(str(ans2))
# Out:
# Empty DataFrame
# Columns: []
# Index: [Kuwait]

# %%
ans3a = gapminder.groupby("continent")[['lifeExp']].agg(['mean', 'std', 'median'])
ans3a.columns = [" ".join(c) for c in ans3a.columns.to_flat_index()]
# ans3b = ans3a.sort_values(by = 'lifeExp median',ascending=False)

print(ans3a)
ans3b = ans3a.sort_values(by = 'lifeExp median',ascending=False)
print(ans3b)
# Out:
#            lifeExp mean  lifeExp std  lifeExp median
# continent
# Africa        48.865330     9.150210         47.7920
# Americas      64.658737     9.345088         67.0480
# Asia          60.064903    11.864532         61.7915
# Europe        71.903686     5.433178         72.2410
# Oceania       74.326208     3.795611         73.6650
#            lifeExp mean  lifeExp std  lifeExp median
# continent
# Oceania       74.326208     3.795611         73.6650
# Europe        71.903686     5.433178         72.2410
# Americas      64.658737     9.345088         67.0480
# Asia          60.064903    11.864532         61.7915
# Africa        48.865330     9.150210         47.7920

# %%
def column_range(col):
    return col.max() - col.min()

column_range(gapminder["lifeExp"])
# Out:
# np.float64(59.00399999999999)

# %%
gapminder.groupby("continent")[['gdpPercap']].agg(['mean', 'std', 'median'])

# %%
result = gapminder.groupby('Entity').agg({'Column': 'sum'}).max()
entity_with_max_sum = result['Column'].idxmax()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 result = gapminder.groupby('Entity').agg({'Column': 'sum'}).max()
#       2 entity_with_max_sum = result['Column'].idxmax()
#
# File ~/PycharmProjects/PythonProject-Test22July/.venv/lib/python3.13/site-packages/pandas/core/frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
# gapminder.sort_values(by=['year'])
gapminder["gdpPercap"].isna()
# Out:
# 334    False
# 335    False
# 876    False
# 624    False
# 333    False
#        ...
# 855    False
# 854    False
# 852    False
# 856    False
# 853    False
# Name: gdpPercap, Length: 1704, dtype: bool

# %%
sns.lineplot(x="year", y="lifeExp", data=gapminder)
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.barplot(x="year", y="gdpPercap", data=gapminder)
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
sns.heatmap(data=gapminder(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 sns.heatmap(data=gapminder(), annot=True)
#
# TypeError: 'DataFrame' object is not callable

# %%
gapminder
# Out:
#               country continent  year  lifeExp       pop      gdpPercap  \
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852     241.165876
# 335  Congo, Dem. Rep.    Africa  2007   46.462  64606759     277.551859
# 876           Lesotho    Africa  1952   42.138    748747     298.846212
# 624     Guinea-Bissau    Africa  1952   32.500    580653     299.850319
# 333  Congo, Dem. Rep.    Africa  1997   42.587  47798986     312.188423
# ..                ...       ...   ...      ...       ...            ...
# 855            Kuwait      Asia  1967   64.624    575003   80894.883260
# 854            Kuwait      Asia  1962   60.470    358266   95458.111760
# 852            Kuwait      Asia  1952   55.565    160000  108382.352900
# 856            Kuwait      Asia  1972   67.712    841934  109347.867000
# 853            Kuwait      Asia  1957   58.033    212846  113523.132900
#
#     iso_alpha  iso_num
# 334       COD      180
# 335       COD      180
# 876       LSO      426
# ...

# %%
total_gdp_year = gapminder.groupby("year").agg(sum)
print([total_gdp_year])
# Out:
# [                                                country  \
# year
# 1952  LesothoGuinea-BissauEritreaMyanmarBurundiEthio...
# 1957  LesothoEritreaMyanmarEthiopiaBurundiMalawiEqua...
# 1962  BurundiEritreaMyanmarLesothoEthiopiaMalawiChin...
# 1967  MyanmarBurundiEritreaMalawiLesothoRwandaEthiop...
# 1972  MyanmarCambodiaBurundiLesothoEritreaEthiopiaMa...
# 1977  MyanmarMozambiqueEritreaCambodiaBurundiEthiopi...
# 1982  MyanmarMozambiqueEritreaBurundiLiberiaEthiopia...
# 1987  MyanmarMozambiqueLiberiaEritreaEthiopiaGambiaU...
# 1992  MyanmarMozambiqueEthiopiaCongo, Dem. Rep.Malaw...
# 1997  Congo, Dem. Rep.MyanmarBurundiMozambiqueEthiop...
# 2002  Congo, Dem. Rep.BurundiEthiopiaLiberiaGuinea-B...
# 2007  Congo, Dem. Rep.LiberiaBurundiZimbabweGuinea-B...
#
#                                               continent     lifeExp  \
# year
# 1952  AfricaAfricaAfricaAsiaAfricaAfricaAsiaAfricaAf...  6966.18200
# 1957  AfricaAfricaAsiaAfricaAfricaAfricaAfricaAfrica...  7314.05096
# ...

# %%
china_gdp = gapminder.query("country == 'China'").set_index("year")
china_gdp
# Out:
#      country continent   lifeExp         pop    gdpPercap iso_alpha  iso_num
# year
# 1952   China      Asia  44.00000   556263527   400.448611       CHN      156
# 1962   China      Asia  44.50136   665770000   487.674018       CHN      156
# 1957   China      Asia  50.54896   637408000   575.987001       CHN      156
# 1967   China      Asia  58.38112   754550000   612.705693       CHN      156
# 1972   China      Asia  63.11888   862030000   676.900092       CHN      156
# 1977   China      Asia  63.96736   943455000   741.237470       CHN      156
# 1982   China      Asia  65.52500  1000281000   962.421381       CHN      156
# 1987   China      Asia  67.27400  1084035000  1378.904018       CHN      156
# 1992   China      Asia  68.69000  1164970000  1655.784158       CHN      156
# 1997   China      Asia  70.42600  1230075000  2289.234136       CHN      156
# 2002   China      Asia  72.02800  1280400000  3119.280896       CHN      156
# ...

# %%
total_gdp_year = gapminder.groupby("year").agg(sum)["gdpPercap"]
[total_gdp_year]
# Out:
# /var/folders/g6/j22cb4pd2bj6ymv0l2glrvkr0000gn/T/ipykernel_998/1494136343.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_gdp_year = gapminder.groupby("year").agg(sum)["gdpPercap"]
# [year
#  1952    5.289892e+05
#  1957    6.105160e+05
#  1962    6.710654e+05
#  1967    7.786787e+05
#  1972    9.613518e+05
#  1977    1.038470e+06
#  1982    1.067684e+06
#  1987    1.121931e+06
#  1992    1.158522e+06
#  1997    1.290805e+06
#  2002    1.408334e+06
#  2007    1.658570e+06
#  Name: gdpPercap, dtype: float64]

# %%
china_percentage = china_gdp / total_gdp_year
china_percentage
# Out:
#       1952  1957  1962  1967  1972  1977  1982  1987  1992  1997  2002  2007  \
# year
# 1952   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1962   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1957   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1967   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1972   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1977   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1982   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1987   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1992   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2002   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
px.line([gapminder], x="year", y="gdpPercap", color="Country")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PycharmProjects/PythonProject-Test22July/.venv/lib/python3.13/site-packages/plotly/express/_core.py:1560, in build_dataframe(args, constructor)
#    1558 try:
#    1559     args["data_frame"] = nw.from_native(
# -> 1560         pd.DataFrame(args["data_frame"])
#    1561     )
#    1562     columns = args["data_frame"].columns
#
# File ~/PycharmProjects/PythonProject-Test22July/.venv/lib/python3.13/site-packages/pandas/core/frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#
# ...

# %%
gapminder.set_index(["year", "country"])
# Out:
#                       continent  lifeExp       pop      gdpPercap iso_alpha  \
# year country
# 2002 Congo, Dem. Rep.    Africa   44.966  55379852     241.165876       COD
# 2007 Congo, Dem. Rep.    Africa   46.462  64606759     277.551859       COD
# 1952 Lesotho             Africa   42.138    748747     298.846212       LSO
#      Guinea-Bissau       Africa   32.500    580653     299.850319       GNB
# 1997 Congo, Dem. Rep.    Africa   42.587  47798986     312.188423       COD
# ...                         ...      ...       ...            ...       ...
# 1967 Kuwait                Asia   64.624    575003   80894.883260       KWT
# 1962 Kuwait                Asia   60.470    358266   95458.111760       KWT
# 1952 Kuwait                Asia   55.565    160000  108382.352900       KWT
# 1972 Kuwait                Asia   67.712    841934  109347.867000       KWT
# 1957 Kuwait                Asia   58.033    212846  113523.132900       KWT
#
#                        iso_num
# ...

# %%
total_gdp_year
# Out:
# year
# 1952    5.289892e+05
# 1957    6.105160e+05
# 1962    6.710654e+05
# 1967    7.786787e+05
# 1972    9.613518e+05
# 1977    1.038470e+06
# 1982    1.067684e+06
# 1987    1.121931e+06
# 1992    1.158522e+06
# 1997    1.290805e+06
# 2002    1.408334e+06
# 2007    1.658570e+06
# Name: gdpPercap, dtype: float64

# %% [markdown]
# ### Module 3 , Assignment 3.3 Colab - Indexing.

# %%
#import necessary libraries
import plotly.express as px
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gapminder = px.data.gapminder()
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
ans1 = gapminder.groupby("year").sum()["gdpPercap"]
ans1
# Out:
# year
# 1952    5.289892e+05
# 1957    6.105160e+05
# 1962    6.710654e+05
# 1967    7.786787e+05
# 1972    9.613518e+05
# 1977    1.038470e+06
# 1982    1.067684e+06
# 1987    1.121931e+06
# 1992    1.158522e+06
# 1997    1.290805e+06
# 2002    1.408334e+06
# 2007    1.658570e+06
# Name: gdpPercap, dtype: float64

# %%
ans2 = gapminder.set_index(["year", "country"])
print(ans2.head())
print(type(ans2))
# Out:
#                  continent  lifeExp       pop   gdpPercap iso_alpha  iso_num
# year country
# 1952 Afghanistan      Asia   28.801   8425333  779.445314       AFG        4
# 1957 Afghanistan      Asia   30.332   9240934  820.853030       AFG        4
# 1962 Afghanistan      Asia   31.997  10267083  853.100710       AFG        4
# 1967 Afghanistan      Asia   34.020  11537966  836.197138       AFG        4
# 1972 Afghanistan      Asia   36.088  13079460  739.981106       AFG        4
# <class 'pandas.core.frame.DataFrame'>

# %%
ans1 = gapminder.groupby('year').sum()[['gdpPercap']]
ans2 = gapminder.set_index(['year', 'country'])
ans3 = ans2["gdpPercap"] / ans1["gdpPercap"]
# ans3 = b['gdpPercap'].div(a['gdpPercap'], level='year').reset_index(name='gdpPercap')
ans3
# Out:
# year  country
# 1952  Afghanistan    0.001473
# 1957  Afghanistan    0.001345
# 1962  Afghanistan    0.001271
# 1967  Afghanistan    0.001074
# 1972  Afghanistan    0.000770
#                        ...
# 1987  Zimbabwe       0.000629
# 1992  Zimbabwe       0.000599
# 1997  Zimbabwe       0.000614
# 2002  Zimbabwe       0.000477
# 2007  Zimbabwe       0.000283
# Name: gdpPercap, Length: 1704, dtype: float64

# %%
ans1 = gapminder.groupby('year').sum()[['gdpPercap']]
ans2 = gapminder.set_index(['year', 'country'])
ans3 = ans2['gdpPercap'].div(ans1['gdpPercap'], level='year').reset_index(name='gdpPercap')
ans3
# Out:
#       year      country  gdpPercap
# 0     1952  Afghanistan   0.001473
# 1     1957  Afghanistan   0.001345
# 2     1962  Afghanistan   0.001271
# 3     1967  Afghanistan   0.001074
# 4     1972  Afghanistan   0.000770
# ...    ...          ...        ...
# 1699  1987     Zimbabwe   0.000629
# 1700  1992     Zimbabwe   0.000599
# 1701  1997     Zimbabwe   0.000614
# 1702  2002     Zimbabwe   0.000477
# 1703  2007     Zimbabwe   0.000283
#
# [1704 rows x 3 columns]

# %%
gapminder.set_index(["year", "country"])
# Out:
#                  continent  lifeExp       pop   gdpPercap iso_alpha  iso_num
# year country
# 1952 Afghanistan      Asia   28.801   8425333  779.445314       AFG        4
# 1957 Afghanistan      Asia   30.332   9240934  820.853030       AFG        4
# 1962 Afghanistan      Asia   31.997  10267083  853.100710       AFG        4
# 1967 Afghanistan      Asia   34.020  11537966  836.197138       AFG        4
# 1972 Afghanistan      Asia   36.088  13079460  739.981106       AFG        4
# ...                    ...      ...       ...         ...       ...      ...
# 1987 Zimbabwe       Africa   62.351   9216418  706.157306       ZWE      716
# 1992 Zimbabwe       Africa   60.377  10704340  693.420786       ZWE      716
# 1997 Zimbabwe       Africa   46.809  11404948  792.449960       ZWE      716
# 2002 Zimbabwe       Africa   39.989  11926563  672.038623       ZWE      716
# 2007 Zimbabwe       Africa   43.487  12311143  469.709298       ZWE      716
#
# [1704 rows x 6 columns]

# %%
# my Answer
# a = gapminder.set_index(["year", "country"])
# b = ans3.set_index(["year", "country"])
# c = a["gdpPercap"] / b["gdpPercap"]
# d = c.reset_index()
# print(d)

# Revise my workings
a = gapminder_indexed = gapminder.set_index(["year", "country"])
b = gdp_sum_by_year = a.groupby("year")["gdpPercap"].sum()
c = gdp_share = a["gdpPercap"]  / gapminder_indexed.groupby('year')['gdpPercap'].sum()
ans4 = c.reset_index()
ans4.columns = ["year", "country", "gdpPercap"]
print(ans4)
# Out:
#       year      country  gdpPercap
# 0     1952  Afghanistan   0.001473
# 1     1957  Afghanistan   0.001345
# 2     1962  Afghanistan   0.001271
# 3     1967  Afghanistan   0.001074
# 4     1972  Afghanistan   0.000770
# ...    ...          ...        ...
# 1699  1987     Zimbabwe   0.000629
# 1700  1992     Zimbabwe   0.000599
# 1701  1997     Zimbabwe   0.000614
# 1702  2002     Zimbabwe   0.000477
# 1703  2007     Zimbabwe   0.000283
#
# [1704 rows x 3 columns]

# %%
# From answer key
gapminder_indexed = gapminder.set_index(['year', 'country'])
gdp_share = gapminder_indexed['gdpPercap'] / gapminder_indexed.groupby('year')['gdpPercap'].sum()
ans4 = gdp_share.reset_index()
ans4.columns = ['year', 'country', 'gdpPercap']
### END SOLUTION

# Answer check
print(ans4)
#print(ans4.head())
# print(type(ans4))
# Out:
#       year      country  gdpPercap
# 0     1952  Afghanistan   0.001473
# 1     1957  Afghanistan   0.001345
# 2     1962  Afghanistan   0.001271
# 3     1967  Afghanistan   0.001074
# 4     1972  Afghanistan   0.000770
# ...    ...          ...        ...
# 1699  1987     Zimbabwe   0.000629
# 1700  1992     Zimbabwe   0.000599
# 1701  1997     Zimbabwe   0.000614
# 1702  2002     Zimbabwe   0.000477
# 1703  2007     Zimbabwe   0.000283
#
# [1704 rows x 3 columns]

# %%
# From Ans Guide

list_of_countries = ['China', 'United States', 'Japan', 'India', 'United Kingdom', 'Germany']
ans5a = None

### BEGIN SOLUTION
gapminder_indexed = gapminder.set_index(['year', 'country'])
gdp_share = gapminder_indexed['gdpPercap'] / gapminder_indexed.groupby('year')['gdpPercap'].sum()
ans4 = gdp_share.reset_index()
ans4.columns = ['year', 'country', 'gdpPercap']
ans5a = ans4.query("country in @list_of_countries")
print(ans5a)
### END SOLUTION

# Answer check
# print(ans5a.head())
# print(type(ans5a))
# Out:
#       year        country  gdpPercap
# 288   1952          China   0.000757
# 289   1957          China   0.000943
# 290   1962          China   0.000727
# 291   1967          China   0.000787
# 292   1972          China   0.000704
# ...    ...            ...        ...
# 1615  1987  United States   0.026637
# 1616  1992  United States   0.027625
# 1617  1997  United States   0.027709
# 1618  2002  United States   0.027761
# 1619  2007  United States   0.025897
#
# [72 rows x 3 columns]

# %%
# Graph Plots from Ans Key

sns.lineplot(data = ans5a, x = 'year', y = 'gdpPercap', hue = 'country')
plt.title('Share of GDP')
plt.xlabel('Year')
plt.ylabel("GDP per capita");

# %%
import pandas as pd

data = {"country":["China", "India", "USA", "China", "India", "USA", "China", "India", "USA"],
       "year":[1960, 1960, 1960, 1990, 1990, 1990, 2017, 2017, 2017],
     "gdp":[1,1,1,6.48, 3.41, 2.94, 79.4, 19.2, 5.62]}
df = pd.DataFrame(data)
print(df)
# Out:
#   country  year    gdp
# 0   China  1960   1.00
# 1   India  1960   1.00
# 2     USA  1960   1.00
# 3   China  1990   6.48
# 4   India  1990   3.41
# 5     USA  1990   2.94
# 6   China  2017  79.40
# 7   India  2017  19.20
# 8     USA  2017   5.62

# %% [markdown]
# ### Assignment 3.4 : Combining Data Analysis

# %%
churn_df = pd.read_csv('/Users/sylvesterprasanna/Documents/001-Berkeley-2025/datasets/cell_phone_churn.csv')
churn_df.head()
# Out:
#   state  account_length  area_code intl_plan vmail_plan  vmail_message  \
# 0    KS             128        415        no        yes             25
# 1    OH             107        415        no        yes             26
# 2    NJ             137        415        no         no              0
# 3    OH              84        408       yes         no              0
# 4    OK              75        415       yes         no              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# ...

# %%
missing_vals = churn_df.isnull().sum()
missing_vals
# Out:
# state             0
# account_length    0
# area_code         0
# intl_plan         0
# vmail_plan        0
# vmail_message     0
# day_mins          0
# day_calls         0
# day_charge        0
# eve_mins          0
# eve_calls         0
# eve_charge        0
# night_mins        0
# night_calls       0
# night_charge      0
# intl_mins         0
# intl_calls        0
# intl_charge       0
# custserv_calls    0
# churn             0
# dtype: int64

# %%
churn_pct = churn_df.value_counts(["churn"], normalize=True)
churn_pct

# churn_df.head()
# churn_df.isnull().sum()
# Out:
# churn
# False    0.855086
# True     0.144914
# Name: proportion, dtype: float64

# %%
sns.countplot(x="churn", data=churn_df)
plt.savefig("churn_count.png")

# %%
churn_df.groupby(["intl_plan",])["churn"].mean()
# Out:
# intl_plan
# no     0.114950
# yes    0.424149
# Name: churn, dtype: float64

# %%
most_churn_ne = None

states = ["NY","MA","CT","NH","ME"]
ne  = churn_df.query("state in @states")
ans = ne.groupby("state",)[["churn"]].mean().sort_values(by='churn', ascending=False)
most_churn_ne = "ME"

print(type(most_churn_ne))
most_churn_ne
# Out:
# <class 'str'>
# 'ME'

# %%
sns.histplot(data=ne, x="intl_mins", hue="churn")
plt.savefig("intl_mins.png")
intl_min_churn = None
intl_min_churn = 'no'

# %%
sns.pairplot(churn_df[['night_calls', 'night_charge', 'intl_mins', 'intl_calls', 'intl_charge', 'custserv_calls', 'churn']], hue="churn")

plt.savefig('pairplot.png.png')

# %%
cust_service_churn = churn_df.groupby(churn_df['custserv_calls'] > 4)[['churn']].mean()

print(type(cust_service_churn))
cust_service_churn
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                    churn
# custserv_calls
# False           0.130260
# True            0.613861
